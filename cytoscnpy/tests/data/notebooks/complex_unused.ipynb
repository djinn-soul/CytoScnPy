# %%
import os
import sys

def process_data(data):
    return data.upper()

# %%
# This function is never called
def unused_helper():
    return 'unused'

# %%
# Actually use the process_data function
result = process_data('hello')
print(result)

# %%
# Import that's never used
import json
import datetime  # This one is unused
