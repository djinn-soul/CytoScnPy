# %%
def used_function():
    return 42

result = used_function()

# %%
def unused_function():
    return 0

# %% [markdown]
# # This is a markdown cell that should be ignored

# %%
class UsedClass:
    def method(self):
        pass

obj = UsedClass()
